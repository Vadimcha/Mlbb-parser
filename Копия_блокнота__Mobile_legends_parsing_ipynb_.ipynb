# %%
import requests
from bs4 import BeautifulSoup
import functools

# %%
def log_function(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        print(f"Begin: {func.__name__}")
        result = func(*args, **kwargs)
        print(f"End {func.__name__}")
        return result
    return wrapper

# %%
@log_function
def getHeroesNames():
    url = 'https://liquipedia.net/mobilelegends/Portal:Heroes'
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        headers = soup.find_all('div', class_="gallerytext")
        heroes = [i.text.strip() for i in headers]
        images = ['https://liquipedia.net' + soup.find('img', alt=i).get('src') for i in heroes]
        return heroes, images
    else:
        print('Ошибка при получении страницы с героями. Код ошибки:', response.status_code)
        return []

# %%
def getHeroStats(name, image):
    url = f'https://liquipedia.net/mobilelegends/{name}'
    response = requests.get(url)
    hero = { 'Name': name, 'Image': image, }
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        infobox_elements = soup.find_all('div', class_='infobox-description')
        for element in infobox_elements:
            label = element.text.strip()
            value = element.find_next_sibling('div').text.strip()
            hero[label.strip(':')] = value.replace(' ┃ 100%', '').replace("\xa0", ' ').replace("\u2003\u2002", '')
        return hero
    else:
        print('Ошибка при получении страницы с героями. Код ошибки:', response.status_code)
        return {}

# %%
@log_function
def getAllHeroesStats(heroesNames, heroesImages):
    heroes = []
    for x in range(len(heroesNames)):
        print(f'Getting {heroesNames[x]} stats: {x + 1}/{len(heroesNames)}')
        heroes.append(getHeroStats(heroesNames[x], heroesImages[x]))
    return heroes

# %%
heroesNames, heroesImages = getHeroesNames()
heroesStats = getAllHeroesStats(heroesNames, heroesImages)
# Out:
# Begin: getHeroesNames
# End getHeroesNames
# Begin: getAllHeroesStats
# Getting Aamon stats: 1/248
# Getting Akai stats: 2/248
# Getting Aldous stats: 3/248
# Getting Alice stats: 4/248
# Getting Alpha stats: 5/248
# Getting Alucard stats: 6/248
# Getting Angela stats: 7/248
# Getting Argus stats: 8/248
# Getting Arlott stats: 9/248
# Getting Atlas stats: 10/248
# Getting Aulus stats: 11/248
# Getting Aurora stats: 12/248
# Getting Badang stats: 13/248
# Getting Balmond stats: 14/248
# Getting Bane stats: 15/248
# Getting Barats stats: 16/248
# Getting Baxia stats: 17/248
# Getting Beatrix stats: 18/248
# Getting Belerick stats: 19/248
# Getting Benedetta stats: 20/248
# Getting Brody stats: 21/248
# Getting Bruno stats: 22/248
# Getting Carmilla stats: 23/248
# Getting Cecilion stats: 24/248
# Getting Chang'e stats: 25/248
# Getting Chip stats: 26/248
# Getting Chou stats: 27/248
# Getting Cici stats: 28/248
# Getting Claude stats: 29/248
# Getting Clint stats: 30/248
# Getting Cyclops stats: 31/248
# Getting Diggie stats: 32/248
# Getting Dyrroth stats: 33/248
# Getting Edith stats: 34/248
# Getting Esmeralda stats: 35/248
# Getting Estes stats: 36/248
# Getting Eudora stats: 37/248
# Getting Fanny stats: 38/248
# Getting Faramis stats: 39/248
# Getting Floryn stats: 40/248
# Getting Franco stats: 41/248
# Getting Fredrinn stats: 42/248
# Getting Freya stats: 43/248
# Getting Gatotkaca stats: 44/248
# Getting Gloo stats: 45/248
# Getting Claude stats: 229/248
# Getting Kimmy stats: 230/248
# Getting Granger stats: 231/248
# Getting Wanwan stats: 232/248
# Getting Popol and Kupa stats: 233/248
# Getting Brody stats: 234/248
# Getting Beatrix stats: 235/248
# Getting Natan stats: 236/248
# Getting Melissa stats: 237/248
# Getting Ixia stats: 238/248
# Getting Rafaela stats: 239/248
# Getting Lolita stats: 240/248
# Getting Estes stats: 241/248
# Getting Diggie stats: 242/248
# Getting Angela stats: 243/248
# Getting Faramis stats: 244/248
# Getting Carmilla stats: 245/248
# Getting Mathilda stats: 246/248
# Getting Floryn stats: 247/248
# Getting Chip stats: 248/248
# End getAllHeroesStats

# %%
print(heroesStats[:30])
# Out:
# [{'Name': 'Aamon', 'Image': 'https://liquipedia.net/commons/images/thumb/1/14/ML_icon_Aamon.png/105px-ML_icon_Aamon.png', 'Price': '32000 599', 'Specialty': 'Chase/Magic Damage', 'Region': 'Moniyan', 'City': 'Castle Aberleen', 'Resource Bar': 'Mana', 'Release Date': '2021-10-25', 'Voice Actor(s)': 'Ishiguro Fumitake', 'Health': '2614', 'Health Regen': '8', 'Mana': '455', 'Mana Regen': '4.2', 'Attack Speed': '1.09', 'Physical Damage': '115', 'Magical Damage': '0', 'Physical Defense': '19', 'Magical Defense': '15', 'Movement Speed': '250', 'Win Rate': '104W : 109L (48.83%)'}, {'Name': 'Akai', 'Image': 'https://liquipedia.net/commons/images/thumb/a/a9/ML_icon_Akai_2022.png/105px-ML_icon_Akai_2022.png', 'Price': '32000', 'Specialty': 'Guard/Crowd Control', 'Region': 'Cadia Riverlands', 'City': 'Stream Valley', 'Resource Bar': 'Mana', 'Release Date': '2016', 'Voice Actor(s)': 'Katagai Nao Chikamatsu Takatsugu', 'Health': '2669', 'Health Regen': '8.4', 'Mana': '422', 'Mana Regen': '2.4', 'Attack Speed': '1.06', 'Physical Damage': '115', 'Magical Damage': '0', 'Physical Defense': '24', 'Magical Defense': '15', 'Movement Speed': '260', 'Win Rate': '1803W : 1823L (49.72%)'}, {'Name': 'Aldous', 'Image': 'https://liquipedia.net/commons/images/thumb/a/a6/ML_icon_Aldous.png/105px-ML_icon_Aldous.png', 'Price': '32000 599', 'Specialty': 'Burst/Support', 'Region': 'Agelta Drylands', 'City': 'Minoan Maze', 'Resource Bar': 'Mana', 'Release Date': '2018', 'Voice Actor(s)': 'Mineta Hiromu Date Masanori', 'Health': '2668', 'Health Regen': '9.8', 'Mana': '405', 'Mana Regen': '3.6', 'Attack Speed': '1.04', 'Physical Damage': '129', 'Magical Damage': '0', 'Physical Defense': '21', 'Magical Defense': '15', 'Movement Speed': '260', 'Win Rate': '117W : 119L (49.58%)'}, {'Name': 'Alice', 'Image': 'https://liquipedia.net/commons/images/thumb/0/09/ML_icon_Alice.png/105px-ML_icon_Alice.png', 'Price': '15000 399', 'Specialty': 'Charge/Regen', 'Region': 'The Barren Lands', 'City': 'Abyss Crack', 'Release Date': '2016', 'Voice Actor(s)': 'Ayase Maria', 'Health': '2573', 'Health Regen': '7.2', 'Mana': '493', 'Mana Regen': '3.6', 'Attack Speed': '1', 'Physical Damage': '114', 'Magical Damage': '0', 'Physical Defense': '21', 'Magical Defense': '15', 'Movement Speed': '240', 'Win Rate': '603W : 606L (49.88%)'}, {'Name': 'Alpha', 'Image': 'https://liquipedia.net/commons/images/thumb/c/c1/ML_icon_Alpha_2021.png/105px-ML_icon_Alpha_2021.png', 'Price': '32000 599', 'Specialty': 'Charge/Damage', 'Region': 'Vonetis Islands', 'City': 'Laboratory 1718', 'Resource Bar': 'Mana', 'Release Date': '2017', 'Voice Actor(s)': 'Satou Yuga', 'Health': '2646', 'Health Regen': '7.8', 'Mana': '453', 'Mana Regen': '6.2', 'Attack Speed': '1.13', 'Physical Damage': '121', 'Magical Damage': '0', 'Physical Defense': '25', 'Magical Defense': '15', 'Movement Speed': '260', 'Win Rate': '205W : 212L (49.16%)'}, {'Name': 'Alucard', 'Image': 'https://liquipedia.net/commons/images/thumb/f/f0/ML_icon_Alucard.png/105px-ML_icon_Alucard.png', 'Price': '15000', 'Specialty': 'Chase/Damage', 'Region': 'Moniyan', 'City': 'Monastery of Light', 'Release Date': '2016', 'Voice Actor(s)': 'Yano Masaaki', 'Health': '2621', 'Health Regen': '7.8', 'Mana': '0', 'Mana Regen': '0', 'Attack Speed': '1.12', 'Physical Damage': '123', 'Magical Damage': '0', 'Physical Defense': '21', 'Magical Defense': '15', 'Movement Speed': '260', 'Win Rate': '34W : 48L (41.46%)'}, {'Name': 'Angela', 'Image': 'https://liquipedia.net/commons/images/thumb/6/6a/ML_icon_Angela_2024_v2.png/105px-ML_icon_Angela_2024_v2.png', 'Price': '24000 499', 'Specialty': 'Guard/Support', 'Region': 'Vonetis Islands', 'City': 'Laboratory 1718', 'Resource Bar': 'Mana', 'Release Date': '2018-02-06', 'Voice Actor(s)': 'Tsukiyama Sanoka Ueda Hikaru', 'Health': '2421', 'Health Regen': '6.8', 'Mana': '515', 'Mana Regen': '3.6', 'Attack Speed': '0.99', 'Physical Damage': '115', 'Magical Damage': '0', 'Physical Defense': '15', 'Magical Defense': '15', 'Movement  ...

# %%
@log_function
def getMatchesLinks():
    allLinks = []
    for x in range(33):
        url = 'https://www.gosugamers.net/mobile-legends/matches/results'
        if x:
            url += f'?pageNo={x + 1}'
        print(f"Getting matches link {x + 1}/33", f"From url: {url}")
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            if x:
                print(soup)
            linksBlocks = soup.find_all('a', class_="MuiListItemButton-root")
            links = ['https://www.gosugamers.net' + i["href"] for i in linksBlocks]
            print(links)
            allLinks.extend(links)
        else:
            print(f'Ошибка при получении ссылок на матчи на странице {url}. Код ошибки:', response.status_code)
            return []

getMatchesLinks()
# Out:
#   Cell In[37], line 11
#     soup = BeautifulSoup(response.text, 'html.parser')Stack(
#                                                       ^
# SyntaxError: invalid syntax
